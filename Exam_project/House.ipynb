# %%
#Basic Import
import pandas as pd
import numpy as np
import requests
import json
import keyboard
import os
import threading
import signal
import sys
import time
from concurrent.futures import ThreadPoolExecutor
from bs4 import BeautifulSoup
import re
#Import for Selenium
import logging

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import WebDriverException
search_url = 'https://danbolig.dk/soeg/?o=newest-desc'

#To Break while loops
is_active = True
list_of_links = []

# %% [markdown]
# # Create Selenium functions
#
# **save_webriver_content:** save the
#
# **break_on_escape:** when escape is pressed, the scroller stops.
#
# **selenium_scroller:** open Chrome winow, wait 15 seconds, scroll to bottom. Return links

# %%
logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    filename='script_log.txt',
                    filemode='w')
def save_links(content):
    with open('list_of_links.txt', 'w') as file:
        file.write('\n'.join(content) + ',' + '\n')
        
def pause_program():
    global is_active
    is_active = False

def on_escape_press(event):
    if event.name == 'esc':
        pause_program()

keyboard.on_press(on_escape_press)

def get_links(driver):
    links = driver.find_elements(By.XPATH, "//a[starts-with(@href, '/bolig/')]")
    list_of_links = [link.get_attribute('href') for link in links]
    return list_of_links

def selenium_scroller(search_url):
    global is_active
    is_active = True
    driver = webdriver.Chrome()
    url = search_url
    driver.get(url)
    scroll_height = 0
    last_height = driver.execute_script("return document.body.scrollHeight")
    time.sleep(15)
    property_listings_div = driver.find_element(By.CSS_SELECTOR, 'div.t-search__list')
    #list_of_links = []
    while is_active:
        try:
            driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight;", property_listings_div)
            time.sleep(1)
            new_scroll_height = driver.execute_script("return arguments[0].scrollHeight;", property_listings_div)
            if new_scroll_height == scroll_height:
                break
            scroll_height = new_scroll_height
        except KeyboardInterrupt:
            pause_program()
            break  
        except WebDriverException as e:
            logging.error(f"Selenium error: {e}")
            driver.save_screenshot("screenshot.png")
        except Exception as e:
            logging.exception("An unexpected error occurred")
            driver.save_screenshot("error_screenshot.png")
        except WebDriverException as e:
            logging.error(f"Selenium error: {e}")
            driver.save_screenshot("screenshot.png")
            driver.quit()  # Close the driver
        except Exception as e:
            logging.exception("An unexpected error occurred")
            driver.save_screenshot("error_screenshot.png")
            driver.quit()  # Close the driver
    list_of_links = get_links(driver)
    # Collect links and content
    
    
#    driver.quit()  # Close the driver
    
    return list_of_links

# %% [markdown]
# ## Get, save and print list of links
# Press escape to break scrolling.

# %%
content = selenium_scroller(search_url)
save_links(content)
for i in content:
    print(i)

# %% [markdown]
# ## Load the data from the links
# Get zip code by regex, to separate roadname, zipcode and city in data

# %%
re_zip = r'https://danbolig\.dk/bolig/([^/]+)/(\d+)/'

zip_list = []
table_large = []
table_left = []
table_address = []
top_info_table = []
house_description = []
house_zip = []
house_data = []
def save_dataframe(frame, file_name):
    csv_filename = '{}.csv'.format(file_name)

    # Export the DataFrame to CSV
    frame.to_csv(csv_filename, index=False)
def get_page_content(url_list):
    for url in url_list:
        match = re.search(re_zip, url)
        if match:
            city = match.group(1)
            zip_code = match.group(2)
            zip_list.append(zip_code)
        try:
            print(url)
            # Send a request to the URL and get the content of the webpage
            response = requests.get(url, headers={'name': 'August Jensen', 'email': 'blz957@alumni.ku.dk', 'institution': 'University of Copenhagen'})
            soup = BeautifulSoup(response.content, 'lxml')

            # Access the large main table and add it to the list of large_tables
            info_table_large = soup.find_all('table')[0].find('tbody')
            table_large.append(info_table_large)

            # Access the small table to the left and add it to the list of left_tables
            info_table_small_left = soup.find_all('table')[1].find('tbody')
            table_left.append(info_table_small_left)

            # Access the small info table at the top (address) and add it to the list of top_addresses
            upper_info_table = soup.find_all('div', class_='o-propertyHero__info o-propertyHero__info--desktop')[0]

            # Find the addresses
            addresses = upper_info_table.find('h1')
            table_address.append(addresses)

            # Find house price and other stats
            info_table = upper_info_table.find_all('ul', class_='o-propertyHero__facts')[0]
            top_info_table.append(info_table)

            #Get house description
            description_tags = soup.find_all('div', class_='o-content o-propertyDescription__description a-paragraph')
            print("Number of description tags found:", len(description_tags)) 
            
            for description in description_tags:
                house_description.append(description.get_text(strip=True))
            if len(description_tags) == 0:
                house_description.append('No description available')
            time.sleep(1)
        except IndexError:
            print("IndexError: Skipping this link.")
            continue



def pass_content_to_dataframe():

    for house in range(len(table_large)):
        main_table_dict = {}

        main_table = table_large[house].find_all('td')
        for i in range(0, len(main_table), 2):
            name = main_table[i].text
            value = main_table[i + 1].text
            value = re.sub(r'\s*(m²|kr\.)', '', value)
            main_table_dict[name] = value

        top_table = top_info_table[house].find_all('span')
        for i in range(0, len(top_table), 2):
            name = top_table[i].text
            value = top_table[i + 1].text
            value = re.sub(r'\s*(m²|kr\.)', '', value)
            if name != 'Energimærke':
                main_table_dict[name] = value.strip()

        name = "address"
        value = ' '.join(table_address[house].text.split())
        main_table_dict[name] = value

        # Add description and zip_code fields from the provided lists
        main_table_dict['description'] = house_description[house]
        main_table_dict['zip code'] = zip_list[house]

        house_data.append(main_table_dict)

    df = pd.DataFrame(house_data)
    # Assuming there's a function save_dataframe that saves the DataFrame to a file
    save_dataframe(df, 'content')
    return df

def get_correct_address(row):
    address_parts = row['address'].split()
    
    # Find the index of the zip code in the address parts
    zip_index = address_parts.index(row['zip code'])
    
    # Join the parts to the left of the zip code as the road
    road = ' '.join(address_parts[:zip_index])
    
    # Join the parts to the right of the zip code as the city
    city = ' '.join(address_parts[zip_index + 1:])
    
    return pd.Series({'City': city, 'zip code': row['zip code'], 'Road': road})

# %% [markdown]
# ## Get information

# %%
get_page_content(content)
df = pass_content_to_dataframe()
# Out:
# https://danbolig.dk/bolig/vejle/7100/villa/0950001202-095/
# Number of description tags found: 1
# https://danbolig.dk/bolig/kolding/6000/lejlighed/0170000991-017/
# Number of description tags found: 1
# https://danbolig.dk/bolig/aarhus/8200/lejlighed/2730000448-273/
# Number of description tags found: 1
# https://danbolig.dk/bolig/kerteminde/5290/villa/2590001307-259/
# Number of description tags found: 1
# https://danbolig.dk/bolig/vordingborg/4760/villa/2040000675-204/
# Number of description tags found: 1
# https://danbolig.dk/bolig/mariagerfjord/9500/villa/4750000371-475/
# Number of description tags found: 1
# https://danbolig.dk/bolig/halsnaes/3390/villa/2930000213-293/
# Number of description tags found: 1
# https://danbolig.dk/bolig/vesthimmerlands/9600/villa/2580000393-258/
# Number of description tags found: 1
# https://danbolig.dk/bolig/odense/5260/villa/2590001283-259/
# Number of description tags found: 1
# https://danbolig.dk/bolig/ishoej/2635/villa/2760000207-276/
# Number of description tags found: 1
# https://danbolig.dk/bolig/varde/6862/fritidsbolig/1140000327-114/
# Number of description tags found: 0
# https://danbolig.dk/bolig/slagelse/4200/fritidsbolig/2840000399-284/
# Number of description tags found: 1
# https://danbolig.dk/bolig/aarhus/

# Number of description tags found: 1
# https://danbolig.dk/bolig/guldborgsund/4840/villa/2960000339-296/
# Number of description tags found: 1
# https://danbolig.dk/bolig/ballerup/2750/fritidsbolig/0210000364-021/
# Number of description tags found: 1
# https://danbolig.dk/bolig/silkeborg/8600/villa/2860001015-286/
# Number of description tags found: 1
# https://danbolig.dk/bolig/guldborgsund/4863/villa/2960000185-296/
# Number of description tags found: 1
# https://danbolig.dk/bolig/koebenhavn/2100/lejlighed/3160000558-316/
# Number of description tags found: 1
# https://danbolig.dk/bolig/syddjurs/8550/villa/2880000332-288/
# Number of description tags found: 1
# https://danbolig.dk/bolig/horsens/8700/landejendom/0820000421-082/
# Number of description tags found: 1
# https://danbolig.dk/bolig/syddjurs/8400/fritidsbolig/0150000198-015/
# Number of description tags found: 1
# https://danbolig.dk/bolig/faxe/4690/villa/2910000296-291/
# Number of description tags found: 1
# https://danbolig.dk/bolig/kolding/6000/raekkehus/0170000791-017/
# Number of description tags found: 1
# https://danbolig.dk/bolig/langeland/5932/fritidsbolig/2610000342-261/
# Number of description tags found: 1
# https://danbolig.dk/bolig/hvidovre/2650/lejlighed/0040000418-004/
# Number of description tags found: 1
# https://danbolig.dk/bolig/gladsaxe/2880/villa/1840000269-184/
# Number of description tags found: 1

# %%
response = requests.get('https://danbolig.dk/bolig/vejle/7182/villa/0950001336-095/')
soup = BeautifulSoup(response.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="da">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Kærbøllinghusevej 31 - Villa til Salg - danbolig</title>
# <meta content="telephone=no" name="format-detection">
# <meta content="Villa til Salg på Kærbøllinghusevej 31. Se boligens billeder, plantegning, salgsopstilling, rapporter og nabolag hos danbolig" name="description">
# <meta content="Kærbøllinghusevej 31 - Villa til Salg - danbolig" property="og:title"/>
# <meta content="Villa til Salg på Kærbøllinghusevej 31. Se boligens billeder, plantegning, salgsopstilling, rapporter og nabolag hos danbolig" property="og:description"/>
# <meta content="https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=750&amp;height=500" property="og:image"/>
# <meta content="750" property="og:image:width"/>
# <meta content="500" property="og:image:height"/>
# <meta content="website" property="og:type"/>
# <meta content="https://danbolig.dk/bolig/vejle/7182/villa/0950001336-095/" property="og:url"/>
# <meta content="danbolig" property="og:site_name"/>
# <meta content="da_DK" property="og:locale"/>
# <meta content="Kærbøllinghusevej 31 - Villa til Salg - danbolig" property="twitter:title"/>
# <meta content="Villa til Salg på Kærbøllinghusevej 31. Se boligens billeder, plantegning, salgsopstilling, rapporter og nabolag hos danbolig" property="twitter:description"/>
# <meta content="https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=750&amp;height=500" property="twitter:image"/>
# <meta content="follow, index, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://danbolig.dk/bolig/vejle/7182/villa/0950001336-095/" rel="canonical"/>
# <link as="font" crossorigin="" href="/assets/fonts/poppins-v20-latin-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/fonts/poppins-v20-latin-500.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/fonts/lora-v26-latin-regular.woff2" rel="preload" type="font/woff2"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="/assets/css/swiper@8/swiper-bundle.min.css" rel="stylesheet" type="text/css"/>
# <script async="" data-cbid="232e3ab8-7b4b-4f23-a00c-556607520b6c" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NJKQP9D');</script>
# <!-- End Google Tag Manager -->
# <link href="/assets/css/style.css?v=cDtUfhEQx8IKcrV9_5gD8e-M7VDPaEo860n_goBSgWc" rel="stylesheet"/>
# <script type="application/ld+json">
#         {
#         "@context": "http://schema.org",
#         "@type": "BreadcrumbList",
#         "itemListElement":
#         [
#            {"@type": "ListItem", "position":1, "item": {"@id": "https://danbolig.dk/", "name": "Forside"}},{"@type": "ListItem", "position":2, "item": {"@id": "https://danbolig.dk/bolig/", "name": "Bolig"}}
#         ]
#         }
#     </script>
# <script type="application/ld+json">
# {
#   "@type": [
#     "ImageObject"
#   ],
#   "author": null,
#   "description": "SS 1000X1000",
#   "contentUrl": "/media/v5qfkvtb/ss-1000x1000.png",
#   "@context": "http://schema.org"
# }
# </script><script type="application/ld+json">
# {
#   "@type": [
#     "ImageObject"
#   ],
#   "author": null,
#   "description": "Prisskilt",
#   "contentUrl": "/media/k2bldth5/prisskilt.svg",
#   "@context": "http://schema.org"
# }
# </script><script type="application/ld+json">
# {
#   "@type": [
#     "ImageObject"
#   ],
#   "author": null,
#   "description": "1400X960 Køberrådgivning Brandbillede",
#   "contentUrl": "/media/r35f3djf/1400x960-koeberraadgivning-brandbillede.png",
#   "@context": "http://schema.org"
# }
# </script><script type="application/ld+json">
# {
#   "@type": [
#     "ImageObject"
#   ],
#   "author": null,
#   "description": "Fallback Home",
#   "contentUrl": "/media/1nkdglou/fallback-home.png",
#   "@context": "http://schema.org"
# }
# </script>
# </meta></meta></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NJKQP9D" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div id="app">
# <o-header inline-template="">
# <header class="o-header" role="banner">
# <div class="u-container u-container--fluid">
# <div class="u-row o-header__row">
# <div class="u-col-12 o-header__column">
# <a href="/">
# <img alt="Logo" class="o-header__logo" height="35" onerror="this.onerror=null;this.src='/assets/images/logo.svg';" src="/media/3inm2efn/logo-original.svg" width="152"/>
# </a>
# <o-search-header :search-pages='[
#   {
#     "url": "/soeg/",
#     "name": "Søg bolig"
#   },
#   {
#     "url": "/ejendomsmaegler/",
#     "name": "Find mægler"
#   }
# ]' :texts="{
#                             drawnArea: `Tegn område`,
#                             mapBounds: `kortudsnit`,
#                             placeholder: `Søg på område - på tværs af alle mæglere`,
#                             save: `Gem`,
#                             searchButton: `Søg bolig`,
#                             suggestion: `Eller udforsk kortet`
#                         }" current-url="/bolig/" search-url="soeg/"></o-search-header>
# <div class="o-header__buttons">
# <m-button ga-action="Global knap klik" ga-category="Hovedmenu" ga-indgangsmetode="" ga-label="" inline-template="">
# <a class="m-button o-buttons__button m-button--outlined m-button--global" href="/bestil-salgsvurdering/" ref="button" v-on:click="onClick">
# <span class="m-button__text m-button__textDesktopOnly">Få vurdering</span>
# <span class="m-button__text m-button__textMobileOnly">Få vurdering</span>
# </a>
# </m-button>
# <div class="o-header__profileWrapper">
# <a class="m-button m-button--transparent o-header__profile" href="/login/?redirectUrl=https%3A%2F%2Fkundeportal.danbolig.dk" target="_blank">
# <a-icon class="m-button__icon" name="account_circle"></a-icon>
# <span class="m-button__text">Log ind</span>
# </a>
# </div>
# <button aria-label="Åben hovedmenu" class="m-button m-button--transparent m-button--icon o-header__toggle" title="Åben hovedmenu" type="button" v-on:click="openNavigation">
# <a-icon class="m-button__icon o-header__toggle" name="menu"></a-icon>
# </button>
# </div>
# </div>
# </div>
# </div>
# </header>
# </o-header>
# <portal :order="1" to="modal" v-if="currentModal === 'navigation'">
# <o-navigation :current-parent="1059" inline-template="">
# <div>
# <div class="o-mobileProfile">
# <a class="m-button m-button--outlined o-mobileProfile__button" href="/login/?redirectUrl=https%3A%2F%2Fkundeportal.danbolig.dk" target="_blank">
# <span class="m-button__text o-mobileProfile__buttonText">Log ind</span>
# <a-icon class="m-button__icon" name="account_circle"></a-icon>
# </a>
# </div>
# <nav :class="{ 'isMounted': isMounted }" class="o-navigation">
# <ul class="o-navigation__list">
# <li class="o-navigation__listItem">
# <div class="a-small o-navigation__label">Salg</div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '1353' }" class="o-navigation__actions" id="1353">
# <a class="a-heading3 o-navigation__link" href="/bestil-salgsvurdering/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Book vurdering</span>
# </a>
# </div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '1892' }" class="o-navigation__actions" id="1892">
# <a class="a-heading3 o-navigation__link" href="/boligskoen/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Tjek boligværdi</span>
# </a>
# </div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '-1' }" class="o-navigation__actions" id="-1">
# <a class="a-heading3 o-navigation__link" href="/ejendomsmaegler/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Find ejendomsmægler</span>
# </a>
# </div>
# </li>
# </ul>
# <ul class="o-navigation__list">
# <li class="o-navigation__listItem">
# <div class="a-small o-navigation__label">Køb</div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '1889' }" class="o-navigation__actions" id="1889">
# <a class="a-heading3 o-navigation__link" href="/soeg/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Søg bolig</span>
# </a>
# </div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '4871' }" class="o-navigation__actions" id="4871">
# <a class="a-heading3 o-navigation__link" href="/koeberraadgivning/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Køberrådgivning</span>
# </a>
# </div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '1894' }" class="o-navigation__actions" id="1894">
# <a class="a-heading3 o-navigation__link" href="/koeberkartotek/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Køberkartotek</span>
# </a>
# </div>
# </li>
# <li class="o-navigation__listItem o-navigation__listItem--hasChildren">
# <div :class="{ 'isOpen': activeItem == '4388' }" class="o-navigation__actions" id="4388">
# <a class="a-heading3 o-navigation__link" href="/projektsalg/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Projektsalg</span>
# </a>
# <button aria-label="Klik for at åbne og lukke undermenuen" class="o-navigation__toggleButton" type="button" v-on:click="onToggle"><a-icon class="o-navigation__listItemIcon" name="expand_more"></a-icon></button>
# </div>
# <ul class="o-navigation__list o-navigation__subList">
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Projektsalg" href="/projektsalg/alle-projektsalg/" v-on:click="onMenuItemClick">
#                                                     Alle projektsalg
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '4389' }" class="o-navigation__actions" id="4389">
# <a class="a-heading3 o-navigation__link" href="/udlejning/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Find lejebolig</span>
# </a>
# </div>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '-1' }" class="o-navigation__actions" id="-1">
# <a class="a-heading3 o-navigation__link" href="/nabolag/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Udforsk Vores Nabolag</span>
# </a>
# </div>
# </li>
# </ul>
# <ul class="o-navigation__list">
# <li class="o-navigation__listItem">
# <div class="a-small o-navigation__label">Bliv klogere</div>
# </li>
# <li class="o-navigation__listItem o-navigation__listItem--hasChildren">
# <div :class="{ 'isOpen': activeItem == '1348' }" class="o-navigation__actions" id="1348">
# <a class="a-heading3 o-navigation__link" href="/boligsalg/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Hvis du vil sælge</span>
# </a>
# <button aria-label="Klik for at åbne og lukke undermenuen" class="o-navigation__toggleButton" type="button" v-on:click="onToggle"><a-icon class="o-navigation__listItemIcon" name="expand_more"></a-icon></button>
# </div>
# <ul class="o-navigation__list o-navigation__subList">
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Hvis du vil sælge" href="/boligsalg/foer-salg/" v-on:click="onMenuItemClick">
#                                                     Før salg
#                                                 </a>
# </li>
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Hvis du vil sælge" href="/boligsalg/under-salg/" v-on:click="onMenuItemClick">
#                                                     Under salg
#                                                 </a>
# </li>
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Hvis du vil sælge" href="/boligsalg/efter-salg/" v-on:click="onMenuItemClick">
#                                                     Efter salg
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="o-navigation__listItem o-navigation__listItem--hasChildren">
# <div :class="{ 'isOpen': activeItem == '1350' }" class="o-navigation__actions" id="1350">
# <a class="a-heading3 o-navigation__link" href="/boligkoeb/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Hvis du vil købe</span>
# </a>
# <button aria-label="Klik for at åbne og lukke undermenuen" class="o-navigation__toggleButton" type="button" v-on:click="onToggle"><a-icon class="o-navigation__listItemIcon" name="expand_more"></a-icon></button>
# </div>
# <ul class="o-navigation__list o-navigation__subList">
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Hvis du vil købe" href="/boligkoeb/foer-koeb/" v-on:click="onMenuItemClick">
#                                                     Før køb
#                                                 </a>
# </li>
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Hvis du vil købe" href="/boligkoeb/under-koeb/" v-on:click="onMenuItemClick">
#                                                     Under køb
#                                                 </a>
# </li>
# <li class="o-navigation__listItem o-navigation__subListItem">
# <a class="a-heading3 o-navigation__link" data-trackparentname="Hvis du vil købe" href="/boligkoeb/efter-koeb/" v-on:click="onMenuItemClick">
#                                                     Efter køb
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="o-navigation__listItem">
# <div :class="{ 'isOpen': activeItem == '1368' }" class="o-navigation__actions" id="1368">
# <a class="a-heading3 o-navigation__link" href="/boligmarkeds-abc/" v-on:click="onMenuItemClick">
# <span class="o-navigation__listItemText">Boligmarkeds ABC</span>
# </a>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </o-navigation>
# </portal>
# <main id="top">
# <m-cta-widget :texts="{
#             isHomeEstimateSticker: false,
#             loadTime: {
#                 before: 2000,
#                 after: 0,
#             },
#             showAgain: {
#                 before: 1,
#                 after: 0,
#             },
#             headline: {
#                 before: 'Er din bolig steget i værdi?  ',
#                 after: '',
#             },
#             description: 'Få svar med en gratis vurdering',
#             bgcolor: {
#                 before: 'yellow',
#                 after: '',
#             },
#             button: {
#                 url: {
#                     before: '/bestil-salgsvurdering/',
#                     after: '',
#                 },
#                 text: {
#                     after: '',
#                 },
#                 screenReaderText: {
#                     before: 'Bestil salgsvurdering',
#                     after: '',
#                 }
#
#             },
#             icon: '',
#         }" name="rootWidget-10367020">
# </m-cta-widget>
# <!--
# <section class="a-section">
#     <div class="u-container">
#         <div class="u-row">
#             <div class="u-col-12 lg:u-col-6 lg:u-offset-3">
#                 <p> </p>
#                 <p></p>
#                 <p></p>
#             </div>
#             <div class="u-col-12 lg:u-col-6 lg:u-offset-3">
#             </div>
#         </div>
#     </div>
# </section>
# -->
# <t-property inline-template="">
# <div class="t-property">
# <section class="o-propertyHero">
# <div class="o-propertyHero__content">
# <div class="o-propertyHeroImageGrid o-propertyHero__images hasThree">
# <div class="o-propertyHeroImageGrid__image o-propertyHero__imageContainer">
# <button class="o-propertyHero__imageLink" type="button" v-on:click="openGallery(0)">
# <img alt="Set fra vejen" class="o-propertyHero__image" height="2000" sizes="(min-width: 1600px) 1224px, 100vw" src="https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=600" srcset="
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=600 600w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=900 900w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=1200 1200w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=1500 1500w" width="3000"/>
# </button>
# </div>
# <div class="o-propertyHeroImageGrid__image o-propertyHero__imageContainer">
# <button class="o-propertyHero__imageLink" type="button" v-on:click="openGallery(1)">
# <img alt="Set fra vejen" class="o-propertyHero__image" height="2000" sizes="(min-width: 768px) 20vw, 50vw" src="https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=300" srcset="
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=300 300w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=600 600w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=900 900w" width="3000"/>
# </button>
# </div>
# <div class="o-propertyHeroImageGrid__image o-propertyHero__imageContainer">
# <button class="o-propertyHero__imageLink" type="button" v-on:click="openGallery(2)">
# <img alt="Køkken" class="o-propertyHero__image" height="2000" sizes="(min-width: 768px) 20vw, 50vw" src="https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/be2be7f6654de4442e9efcb7854cfcf5/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=300" srcset="
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/be2be7f6654de4442e9efcb7854cfcf5/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=300 300w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/be2be7f6654de4442e9efcb7854cfcf5/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=600 600w,
#                                     https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/be2be7f6654de4442e9efcb7854cfcf5/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&amp;width=900 900w" width="3000"/>
# <div class="o-propertyHero__imageLinkOverlay">
# <span class="o-propertyHero__imageLinkOverlayIcon"><a-icon name="gallery"></a-icon></span>
# <span>+ 23 Billeder</span>
# </div>
# </button>
# </div>
# <div class="o-propertyHero__labelsGrid">
# <div class="o-propertyHero__propertyLabels">
# </div>
# </div>
# </div>
# </div>
# <div class="u-container u-none md:u-block">
# <div class="u-row">
# <div class="u-col-12 md:u-col-4 lg:u-col-3">
# <div class="o-propertyHero__info o-propertyHero__info--desktop">
# <div class="o-propertyHero__labels">
# <div class="a-label o-propertyHero__label">
#                                 Villa
#                             </div>
# <div class="a-label o-propertyHero__label">
# <span class="o-propertyHero__labelIcon"></span>
#                                 Nyhed!
#                             </div>
# </div>
# <h1 class="a-lead o-propertyHero__address">
#                         Kærbøllinghusevej 31<br/>
#                         7182 Bredsten
#                     </h1>
# <ul class="o-propertyHero__facts">
# <li class="a-label u-none md:u-flex">
# <span>Kontantpris</span>
# <span>
# 3.395.000 kr.                                    </span>
# </li>
# <li class="a-label u-none md:u-flex">
# <span>Ejerudgift</span>
# <span>
# 1.974 kr.                                    </span>
# </li>
# <li class="a-label u-none md:u-flex">
# <span>Boligareal</span>
# <span>
# 120 m²                                    </span>
# </li>
# <li class="a-label u-none md:u-flex">
# <span>Grundareal</span>
# <span>
# 6.064 m²                                    </span>
# </li>
# <li class="a-label u-none md:u-flex">
# <span>Rum</span>
# <span>
# 4                                    </span>
# </li>
# <li class="a-label u-none md:u-flex">
# <span>Energimærke</span>
# <span>
# <a-energy-label name="E"></a-energy-label>
# </span>
# </li>
# </ul>
# </div>
# </div>
# <div class="u-col-12 md:u-col-4 md:u-offset-1 lg:u-col-5">
# </div>
# </div>
# </div>
# </section>
# <section class="a-section">
# <div class="u-container">
# <div class="u-row">
# <div class="u-col-12 md:u-col-7 md:u-offset-5 lg:u-col-8 lg:u-offset-4">
# <o-anchors tracking-category-name="Boligpraesentation" tracking-name="trackBoligpraesentation"></o-anchors>
# </div>
# </div>
# </div>
# </section>
# <section class="o-propertyHero o-propertyHero--mobile md:u-none">
# <div class="u-container">
# <div class="u-row">
# <div class="u-col-12">
# <div class="o-propertyHero__info o-propertyHero__info--mobile">
# <div class="o-propertyHero__labels">
# <div class="a-label o-propertyHero__label">Villa</div>
# <div class="a-label o-propertyHero__label">
# <span class="o-propertyHero__labelIcon"></span>
#                                 Nyhed!
#                             </div>
# </div>
# <h1 class="a-lead o-propertyHero__address">
#                         Kærbøllinghusevej 31<br/>
#                         7182 Bredsten
#                     </h1>
# <ul class="o-propertyHero__facts">
# <li class="a-label">
# <span>3.395.000 kr.</span>
# <span>120 m²</span>
# <span>4 rum</span>
# <a-energy-label name="E"></a-energy-label>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="a-section o-propertySection">
# <div class="u-container">
# <div class="u-row">
# <div class="u-col-12 md:u-col-7 md:u-offset-5 lg:u-col-8 lg:u-offset-4">
# <div class="o-propertyDescription">
# <o-property-views :list='[
#   {
#     "count": 1,
#     "text": "1 dokumenter downloadet",
#     "type": "downloads",
#     "visibleCount": 0,
#     "visible": true
#   }
# ]' :showing-stats='{
#   "days": 7,
#   "text": "#visninger# visninger de seneste 7 dage",
#   "type": "views",
#   "visibleCount": 20,
#   "hidePageViews": false
# }' broker-id="095" property-id="0950001336">
# </o-property-views>
# <h2 class="a-heading2 o-propertyDescription__title">
#                             Villa i de smukke bakker af Vejle Ådal
#                         </h2>
# <div class="o-propertyDescription__overlayLinks">
# <m-modal-opener :modal="'property'" :panel="'broker'" :tracking-data="{
#                                 name: `trackForm`,
#                                 category: `Formular`,
#                                 action: `Kontakt maegler initieret`,
#                                 label: `Kontakt maegler`,
#                                 formularIndgang: `Link`,
#                                 formularSektion: `Kontakt maegler`,
#                                 formularStepnavn: `Brugerinformation`,
#                                 maeglerId: `095`
#                             }" inline-template="">
# <button class="a-label a-anchor a-anchor--secondary" v-on:click="onClick">Kontakt ejendomsmægler</button>
# </m-modal-opener>
# <m-modal-opener :modal="'property'" :panel="'material'" :tracking-data="{
#                                     name: `trackForm`,
#                                     category: `Formular`,
#                                     action: `Hent salgsmateriale initieret`,
#                                     label: `Hent salgsmateriale`,
#                                     formularIndgang: `Link`,
#                                     formularStepnavn: `Brugerinformation`,
#                                     maeglerId: `095`
#                                  }" inline-template="">
# <button class="a-label a-anchor a-anchor--secondary" v-on:click="onClick">Hent salgsdokumenter</button>
# </m-modal-opener>
# <m-modal-opener :modal="'property'" :panel="'showing'" :tracking-data="{
#                                     name: `trackForm`,
#                                     category: `Formular`,
#                                     action: `Bestil fremvisning initieret`,
#                                     label: `Bestil fremvisning`,
#                                     formularIndgang: `Link`,
#                                     formularSektion: `Bestil fremvisning`,
#                                     formularStepnavn: `Vaelg dato`,
#                                     maeglerId: `095`
#                                  }" inline-template="">
# <button class="a-label a-anchor a-anchor--secondary" v-on:click="onClick">Bestil fremvisning</button>
# </m-modal-opener>
# </div>
# <div class="o-content o-propertyDescription__description a-paragraph">
# <o-hidden-text>
#                                 For jer som ønsker at bo i smuk, fredet natur og samtidig tæt på alt - inkl. Vejle centrum.<br/> <br/>Et sjældent udbud - beliggende i noget af Danmarks skønneste natur, på ydersiden af bydelen Skibet med kun 8 minutter til Vejles gågade/centrum. Vinkelvillaen er smukt beliggende i starten af Vejle Ådal placeret højt på en stor grund (godt 6.000 m2 med mulighed for afgræsning/dyrehold) og omgivet af så betagende smuk natur at man må knibe sig i armen.<br/> <br/>Villaen er renoveret og opgraderet flere gange, bl.a. med hvidt HTH-køkken med integrerede hvidevarer og bad i eg samt gulve af askeplank, – senest med ny Vølund varmepumpe (lavt varmeforbrug). Boligen er meget funktionelt indrettet med entre/gang, vinkelstue, tre værelser, køkken, badeværelse og stort grovkøkken, i alt 120 m2 boligareal, - dertil kommer sambygget 16 m2 stort fyrrum – i alt 136 m2. Desuden dobbelt garage, - en dobbelt carport, - samt drivhus med frodig økologisk vinplante.<br/> <br/>Ved villaen er der nyanlagt hele 4 terrasser (nu i alt 5), - samt anlagt let-at-holde blomsterhaver. Desuden rummer grunden mange frugttræer - samt frugtbuske. Haven er stor – men er ikke anlagt så I ”drukner” i havearbejde, fordi en del af grunden i dag er ”vild” natur og rummer bl.a. en idyllisk bæk og en lille sø, - I har således masser tid til at nyde familielivet. Stedet har et helt fantastisk dyre- og fugleliv, bl.a. hjorte, ræv og egern samt masser af sangfugle forår og sommer.<br/> <br/>Beliggenheden er unik – samtidig går I ikke på kompromis med nærheden med gå/cykleafstand 2 km. ad sti til børnehave, skole, hal og sportsklubber m.m.. Kun 4 km. til dagligvarebutik. Gang/cykelsti til Vejle centrum. 700 m. til busstoppested.<br/> <br/>Stedet han opleves på en fremvisning, - kun seriøse henvendelser. Kontakt ansvarlig ejendomsmægler Torben Pedersen 40 10 96 80 for nærmere drøftelse.
#                             </o-hidden-text>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="a-section">
# <div class="u-container">
# <div class="u-row">
# <div class="u-col-12">
# <div data-anchor-icon="blueprint" data-anchor-screenreader-text="Link til plantegningen" data-anchor-text="Plantegning" data-sort-order="1" id="plan"></div>
# <o-property-floorplan :floorplan-interactive='[
#   {
#     "id": 536371,
#     "name": "Stueplan",
#     "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTI1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/76a09fc83f644f5ca2d495aa41da49c3/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "hotspots": [
#       {
#         "id": 2572268,
#         "data": {
#           "x": 42.31845727198027,
#           "y": 41.08527629416597,
#           "deg": "90"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTExLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/1067cdd4c336d367f96ac034d8024c87/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572252,
#         "data": {
#           "x": 62.53209737058341,
#           "y": 34.01871918652424,
#           "deg": "0"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE3LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5306752018e7341b36519ae44f40fcb6/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572239,
#         "data": {
#           "x": 47.49512119967133,
#           "y": 36.31945870994248,
#           "deg": "232.54942176826327"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA5LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/14669422ba0e120211acafa2ee87932e/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572265,
#         "data": {
#           "x": 56.944587099424815,
#           "y": 32.08774137222679,
#           "deg": "90"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/800c06af33e98641c5941a359c0a0468/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572241,
#         "data": {
#           "x": 38.04565529991782,
#           "y": 34.59390406737879,
#           "deg": "180"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/e53f3102d792c1a6b7be0c6b221152a1/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572242,
#         "data": {
#           "x": 28.185343056696794,
#           "y": 36.56596651602301,
#           "deg": "180"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/be2be7f6654de4442e9efcb7854cfcf5/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572240,
#         "data": {
#           "x": 28.924866474938373,
#           "y": 29.74591721446179,
#           "deg": "0"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA3LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/389bc59a608385290395ca85f1633d67/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572260,
#         "data": {
#           "x": 26.54195768282662,
#           "y": 48.06966413311421,
#           "deg": "0"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/7301a61745c2d2bccf7e67c46df09dcb/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572245,
#         "data": {
#           "x": 28.760527937551355,
#           "y": 56.28659100246509,
#           "deg": "45"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2b51ef3edf51e356c9a25483062a9ab1/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572243,
#         "data": {
#           "x": 23.337356203779787,
#           "y": 56.5330988085456,
#           "deg": "0"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/0c6f14f272ed5270af3f7258443a57d8/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572244,
#         "data": {
#           "x": 23.66603327855382,
#           "y": 63.76399445357436,
#           "deg": "90"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2509fd0d66138b92596a440889e75b2a/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572257,
#         "data": {
#           "x": 11.011965899753493,
#           "y": 68.69415057518486,
#           "deg": "225"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/1656435517e75de5628f33bbe3495739/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572238,
#         "data": {
#           "x": 16.681645439605585,
#           "y": 42.64649239934264,
#           "deg": "45"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/8d8dd6002540c7c9446113cd2dbb787b/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572253,
#         "data": {
#           "x": 20.132754724732948,
#           "y": 32.662926253081345,
#           "deg": "90"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c9167dab3a533548a186cb65f9d24ac9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572250,
#         "data": {
#           "x": 5.095778553820871,
#           "y": 78.06144720624486,
#           "deg": "360"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE5LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2e0392f01f3bb761cfe8a65a600f2114/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572246,
#         "data": {
#           "x": 37.388301150369756,
#           "y": 78.06144720624486,
#           "deg": "135"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572248,
#         "data": {
#           "x": 83.32092235004109,
#           "y": 69.43367399342645,
#           "deg": "107.16191880286529"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/89fd00cfd3c986cda3f833f520694cc7/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572247,
#         "data": {
#           "x": 88.1689092029581,
#           "y": 6.4098449055053415,
#           "deg": "25.651528465052557"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAxLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5297d9038b0daf801a9f8d5a59373860/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       },
#       {
#         "id": 2572251,
#         "data": {
#           "x": 17.749845932621195,
#           "y": 17.83137325390304,
#           "deg": "180"
#         },
#         "file": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c84189b258159e5e6b173ac7228d47e9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23"
#       }
#     ]
#   }
# ]' :floorplan2d='[
#   {
#     "description": "Stueplan",
#     "height": 3000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTI1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTI1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/76a09fc83f644f5ca2d495aa41da49c3/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "previewUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTI1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/76a09fc83f644f5ca2d495aa41da49c3/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "type": "Plantegning"
#   }
# ]' :floorplan3d="[]" :texts="{
#                             interactive: `Interaktiv`,
#                             threeDimensional: `3D`,
#                             twoDimensional: `2D`,
#                         }" headline="Plantegning" property-id="0950001336"></o-property-floorplan>
# </div>
# </div>
# </div>
# </section>
# <section class="a-section" data-type="propertyPresentationInNumbers">
# <div class="u-container">
# <div data-anchor-icon="home_data_2" data-anchor-screenreader-text="Boligen i tal" data-anchor-text="Boligfakta" data-sort-order="3" id="Fakta"></div>
# <div class="u-row">
# <div class="u-col-12 lg:u-col-10 lg:u-offset-1">
# <div class="o-propertyPresentationInNumbers">
# <div class="o-propertyPresentationInNumbers__wrapper">
# <div class="m-table o-propertyPresentationInNumbers__table">
# <table data-propertytype="Villa">
# <thead>
# <tr>
# <th colspan="2">Boligfakta</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Type</td>
# <td>Villa</td>
# </tr>
# <tr>
# <td>Udbudsform</td>
# <td>Salg</td>
# </tr>
# <tr>
# <td>Energimærke</td>
# <td>E</td>
# </tr>
# <tr>
# <td>Varmekilde</td>
# <td>Varmepumpe</td>
# </tr>
# <tr>
# <td>Byggeår</td>
# <td>1962</td>
# </tr>
# <tr>
# <td>Rum</td>
# <td>4</td>
# </tr>
# <tr>
# <td>Bad</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Toilet</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Boligareal</td>
# <td>120 m²</td>
# </tr>
# <tr>
# <td>Carport</td>
# <td>53 m²</td>
# </tr>
# <tr>
# <td>Garage/udhus</td>
# <td>53 m²</td>
# </tr>
# <tr>
# <td>Grundareal</td>
# <td>6.064 m²</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="m-table o-propertyPresentationInNumbers__table">
# <table>
# <thead>
# <tr>
# <th colspan="2">Økonomi</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Kontantpris</td>
# <td>3.395.000 kr.</td>
# </tr>
# <tr>
# <td>Ejerudgift</td>
# <td>1.974 kr.</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="o-buttons o-propertyPresentationInNumbers__buttons">
# <m-modal-opener :fixed="true" :modal="'property'" :panel="'material'" :tracking-data="{
#                                         name: `trackForm`,
#                                         category: `Formular`,
#                                         action: `Hent salgsmateriale initieret`,
#                                         label: `Hent salgsmateriale`,
#                                         formularIndgang: `Faktaboks`,
#                                         formularStepnavn: `Brugerinformation`,
#                                         maeglerId: `095`
#                                        }" inline-template="">
# <button aria-label="Åben salgsmateriale" class="m-button o-buttons__button o-propertyPresentationInNumbers__button" type="button" v-on:click="onClick">
#                                             Hent salgsdokumenter
#                                             <a-icon class="o-propertyPresentationInNumbers__buttonIcon" name="download"></a-icon>
# </button>
# </m-modal-opener>
# </div>
# <div class="o-buttons o-propertyPresentationInNumbers__buttons">
# <a class="m-button o-buttons__button m-button--link m-button--underlined" data-tracknordealink="" href="https://www.nordea.dk/privat/produkter/boliglaan/hvad-koster-det-at-laane-til-koeb-af-bolig.html?cid=partner-dpx1pj9kg1#?propertyType=villa&amp;propertyPrice=3395000&amp;propertyPayout=0">
#                                             Beregn boliglån hos Nordea
#                                         </a>
# <a class="m-button o-buttons__button m-button--link m-button--underlined" data-tracknordealink="" href="https://www.nordea.dk/privat/produkter/boliglaan/laanebevis.html?cid=partner-f4f4hzz0y2">
#                                             Få et bevis på, hvad du kan købe bolig for hos Nordea
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="a-section">
# <div class="u-container">
# <div class="u-row">
# <div class="u-col-12 lg:u-col-7 lg:u-offset-3">
# <div class="o-moduleSmallCampaign o-moduleSmallCampaign--whiteShadow">
# <div class="o-moduleSmallCampaign__content">
# <p class="o-moduleSmallCampaign__contentHeadline">Skal vi også sælge din bolig?</p>
# <p>
# <a class="a-anchor" data-ga-action="Klik paa CTA" data-ga-category="Boligpraesentation" data-ga-label="Faa vurdering" data-track-small-campaign="" href="/bestil-salgsvurdering/" target="_blank">
#                                     Find ud af, hvad din bolig er værd
#                                     <a-icon name="arrow_forward"></a-icon>
# </a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="a-section" data-type="propertyDetailsList">
# <div class="u-container">
# <o-property-details-list inline-template="">
# <div class="o-propertyDetailsList">
# <o-property-details :details-id="1" :images='[
#   {
#     "description": "Set fra vejen",
#     "height": 2000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "previewUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/b8cf435265cb60247f1e282bc53d302c/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "type": "Billede"
#   },
#   {
#     "description": "Set fra haven",
#     "height": 2000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAxLCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAxLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5297d9038b0daf801a9f8d5a59373860/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "previewUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAxLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5297d9038b0daf801a9f8d5a59373860/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "type": "Billede"
#   },
#   {
#     "description": "Udendørs",
#     "height": 2000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c84189b258159e5e6b173ac7228d47e9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "previewUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c84189b258159e5e6b173ac7228d47e9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "type": "Billede"
#   },
#   {
#     "description": "Udendørs",
#     "height": 2000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/72a9459b1c2eaa2ebf072713fd55fdd8/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "previewUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/72a9459b1c2eaa2ebf072713fd55fdd8/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "type": "Billede"
#   },
#   {
#     "description": "Have",
#     "height": 2000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/0a548331c0fd5ca310f0dd670812d1ef/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "previewUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/0a548331c0fd5ca310f0dd670812d1ef/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#     "type": "Billede"
#   }
# ]'>
# <template v-slot:headline="">
# <h2 class="a-heading3 o-propertyDetails__detailsHeadline">
#                                     Nyd udsigten
#                                 </h2>
# </template>
# <template v-slot:description="">
# <p class="a-paragraph">
#                                     Den cirka 6.000 kvm store grund er omkranset til to sider af Fredskov, hvilket understreger den fantastiske beliggenhed. På grunden er der egen bæk og en lille sø, og alle fem terrasser er placeret højt på grunden sammen med huset, så I får fuldt udbytte af udsigten over Vejle Ådal. Den ene terrasse mod syd har endda en fjernstyret markise.
#                                 </p>
# </template>
# </o-property-details>
# <o-property-details :details-id="2" :images='[
#   {
#     "description": "Køkken",
#     "height": 2000,
#     "width": 3000,
#     "id": "SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9",
#     "url": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/be2be7f6654de4442e9efcb7854cfcf5/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
# ...
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/1656435517e75de5628f33bbe3495739/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/1656435517e75de5628f33bbe3495739/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2509fd0d66138b92596a440889e75b2a/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2509fd0d66138b92596a440889e75b2a/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/8d8dd6002540c7c9446113cd2dbb787b/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/8d8dd6002540c7c9446113cd2dbb787b/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA5LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/14669422ba0e120211acafa2ee87932e/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA5LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/14669422ba0e120211acafa2ee87932e/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/800c06af33e98641c5941a359c0a0468/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTEyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/800c06af33e98641c5941a359c0a0468/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTExLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/1067cdd4c336d367f96ac034d8024c87/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTExLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/1067cdd4c336d367f96ac034d8024c87/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2f21a96a5fb7abdbff167036fb13cc82/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE1LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2f21a96a5fb7abdbff167036fb13cc82/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c9167dab3a533548a186cb65f9d24ac9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE2LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c9167dab3a533548a186cb65f9d24ac9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/e53f3102d792c1a6b7be0c6b221152a1/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTA4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/e53f3102d792c1a6b7be0c6b221152a1/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE3LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5306752018e7341b36519ae44f40fcb6/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE3LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5306752018e7341b36519ae44f40fcb6/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3ODk4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/f297b84128c9745671f037fbe1934819/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3ODk4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/f297b84128c9745671f037fbe1934819/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAxLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5297d9038b0daf801a9f8d5a59373860/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTAxLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/5297d9038b0daf801a9f8d5a59373860/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/a5c12d773b47bda06f353ab6b707301d/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIwLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/a5c12d773b47bda06f353ab6b707301d/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE5LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2e0392f01f3bb761cfe8a65a600f2114/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE5LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/2e0392f01f3bb761cfe8a65a600f2114/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c84189b258159e5e6b173ac7228d47e9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTE4LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/c84189b258159e5e6b173ac7228d47e9/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/72a9459b1c2eaa2ebf072713fd55fdd8/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIyLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/72a9459b1c2eaa2ebf072713fd55fdd8/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/0a548331c0fd5ca310f0dd670812d1ef/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTIzLCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/0a548331c0fd5ca310f0dd670812d1ef/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     },
#     {
#       "@type": "MediaObject",
#       "contentUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTI0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/a079857a350ed97d57e112c0ced569ab/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23",
#       "thumbnailUrl": "https://danbolig.mindworking.eu/api/mediaData/mediaDataMediaPurposeId/SU1lZGlhRGF0YTp7Ik1lZGlhRGF0YUlkIjo1NzI3OTI0LCJNZWRpYVB1cnBvc2VJZCI6MjJ9/imageHash/a079857a350ed97d57e112c0ced569ab/imageSize/assets/inline/true?deviceid=DB_mnvxs43mnbn23&width=700"
#     }
#   ],
#   "@context": "http://schema.org"
# }
# </script>
# </main>
# <o-modal close-label="Luk"></o-modal>
# <footer class="o-footer" role="contentinfo">
# <div class="u-container">
# <div class="u-row">
# <div class="u-col-12 lg:u-col-6 lg:u-order-2 o-footer__newsletterColumn">
# <div class="o-footer__newsletter">
# <h2 class="a-heading3 o-footer__title">Vil du have nyheder fra danbolig?</h2>
# <o-form action="/nyhedsbrev/" form-section="Footer" method="get">
# <m-input button-text="Gå til tilmelding af nyhedsbrev formular" class="o-footer__input" icon="arrow_forward" name="email" placeholder="Indtast din e-mail" type="email" v-model="footer.form.email"></m-input>
# </o-form>
# </div>
# </div>
# <div class="u-col-12 lg:u-col-6 lg:u-order-1 o-footer__linksColumn">
# <div class="o-footer__links">
# <div class="u-row">
# <div class="u-col-12 md:u-col-4">
# <ul class="o-footer__unorderedList">
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/om-danbolig/vi-er-danbolig/">
# <span class="m-button__text o-footer__linkText">
#                                                 Vi er danbolig
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/om-danbolig/derfor-danbolig/">
# <span class="m-button__text o-footer__linkText">
#                                                 Hvorfor vælge os
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/om-danbolig/kontakt/">
# <span class="m-button__text o-footer__linkText">
#                                                 Kontakt
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# </ul>
# </div>
# <div class="u-col-12 md:u-col-4">
# <ul class="o-footer__unorderedList">
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/om-danbolig/presse/">
# <span class="m-button__text o-footer__linkText">
#                                                 Presse
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/nyheder/">
# <span class="m-button__text o-footer__linkText">
#                                                 Nyheder
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/om-danbolig/job/">
# <span class="m-button__text o-footer__linkText">
#                                                 Job hos danbolig
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# </ul>
# </div>
# <div class="u-col-12 md:u-col-4">
# <ul class="o-footer__unorderedList">
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="https://danboligerhverv.dk">
# <span class="m-button__text o-footer__linkText">
#                                                 danbolig Erhverv
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/projektsalg/">
# <span class="m-button__text o-footer__linkText">
#                                                 Projektsalg
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# <li class="o-footer__listItem">
# <a class="m-button m-button--transparent o-footer__link" data-trackfooter="" href="/udlejning/">
# <span class="m-button__text o-footer__linkText">
#                                                 Find lejebolig
#                                             </span>
# <a-icon class="m-button__icon o-footer__linkIcon" name="arrow_forward"></a-icon>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="o-footer__disclaimer">
# <p>Vi bruger <a data-anchor="#samtykke" href="/cookie-og-privatlivspolitik/cookiepolitik/#samtykke" title="Cookiepolitik">cookies</a> for at give dig den bedste oplevelse på danbolig.dk. <a href="/cookie-og-privatlivspolitik/" title="Cookie- og privatlivspolitik">Læs vores cookie- og privatlivspolitik</a>.</p>
# <p>danbolig samarbejder med <strong><a href="https://www.nordea.dk/">Nordea</a></strong></p>
# </div>
# </div>
# </footer>
# <a-grid-overlay></a-grid-overlay>
# </div>
# <script src="/assets/js/script.js?v=NWfmdXJVO_NtLG3ees77PpE4y1jRqdDq-iuOVAyKYXQ" type="application/javascript"></script>
# <script>
#         if (window.dataLayer !== undefined) {
#             window.dataLayer.push({
#                 event: "trackPageview",
#                 eventData: {
#                     loggedIn: "false"
#                 }
#             });
#         }
#     </script>
# </body>
# </html>
